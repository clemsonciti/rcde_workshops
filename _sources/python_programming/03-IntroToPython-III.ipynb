# %% [markdown]
# # Introduction to Python III
#
# Introduction to Pandas and some more Matplotlib functionality!

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Pandas Introduction

# %%
#Importing a list as a series into Pandas
series1 = pd.Series(["Straw", "Hello", "Berry", "Tigers"])
series1
# Out:
# 0     Straw
# 1     Hello
# 2     Berry
# 3    Tigers
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
#date range object
dates = pd.date_range('20220624', periods = 10) 
dates
# Out:
# DatetimeIndex(['2022-06-24', '2022-06-25', '2022-06-26', '2022-06-27',
#                '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01',
#                '2022-07-02', '2022-07-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
#pd.date_range? 
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ## Dataframe
# Data Structure that contains data in a tabular format and can be labeled and indexed. This structure can be changed and can contain different data/object types

# %%
#Dataframe
df = pd.DataFrame(np.random.randint(3, 8, (10,5)), index = dates, columns = ('A', 'B', 'C', 'D', 'E'))

# %%
#Generating a random matrix/2Darray of size 10x5
test = np.random.randint(3, 8, (10,5)) 
test[:,2]
# Out:
# array([5, 6, 5, 6, 7, 7, 7, 5, 4, 5])

# %%
df
# Out:
#             A  B  C  D  E
# 2022-06-24  7  3  3  4  5
# 2022-06-25  5  5  7  3  3
# 2022-06-26  6  6  6  3  3
# 2022-06-27  6  7  5  6  3
# 2022-06-28  5  3  6  4  6
# 2022-06-29  7  7  3  6  5
# 2022-06-30  6  6  7  7  7
# 2022-07-01  5  5  7  7  7
# 2022-07-02  5  5  3  4  6
# 2022-07-03  7  3  5  6  4

# %%
df.T # transpose
# Out:
#    2022-06-24  2022-06-25  2022-06-26  2022-06-27  2022-06-28  2022-06-29  \
# A           7           5           6           6           5           7
# B           3           5           6           7           3           7
# C           3           7           6           5           6           3
# D           4           3           3           6           4           6
# E           5           3           3           3           6           5
#
#    2022-06-30  2022-07-01  2022-07-02  2022-07-03
# A           6           5           5           7
# B           6           5           5           3
# C           7           7           3           5
# D           7           7           4           6
# E           7           7           6           4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# describe(): returns general statistics for each column in the dataframe

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    5.900000   5.000000   5.200000   5.000000   4.900000
# std     0.875595   1.563472   1.686548   1.563472   1.595131
# min     5.000000   3.000000   3.000000   3.000000   3.000000
# 25%     5.000000   3.500000   3.500000   4.000000   3.250000
# 50%     6.000000   5.000000   5.500000   5.000000   5.000000
# 75%     6.750000   6.000000   6.750000   6.000000   6.000000
# max     7.000000   7.000000   7.000000   7.000000   7.000000

# %%
#Look at the first n rows
df.head(3)  #default is 5
# Out:
#             A  B  C  D  E
# 2022-06-24  7  3  3  4  5
# 2022-06-25  5  5  7  3  3
# 2022-06-26  6  6  6  3  3

# %%
#look at the last n rows
df.tail(2) #default is 5
# Out:
#             A  B  C  D  E
# 2022-07-02  5  5  3  4  6
# 2022-07-03  7  3  5  6  4

# %%
df.T.describe()
# Out:
#        2022-06-24  2022-06-25  2022-06-26  2022-06-27  2022-06-28  2022-06-29  \
# count     5.00000     5.00000    5.000000    5.000000     5.00000     5.00000
# mean      4.40000     4.60000    4.800000    5.400000     4.80000     5.60000
# std       1.67332     1.67332    1.643168    1.516575     1.30384     1.67332
# min       3.00000     3.00000    3.000000    3.000000     3.00000     3.00000
# 25%       3.00000     3.00000    3.000000    5.000000     4.00000     5.00000
# 50%       4.00000     5.00000    6.000000    6.000000     5.00000     6.00000
# 75%       5.00000     5.00000    6.000000    6.000000     6.00000     7.00000
# max       7.00000     7.00000    6.000000    7.000000     6.00000     7.00000
#
#        2022-06-30  2022-07-01  2022-07-02  2022-07-03
# count    5.000000    5.000000    5.000000    5.000000
# mean     6.600000    6.200000    4.600000    5.000000
# std      0.547723    1.095445    1.140175    1.581139
# ...

# %% [markdown]
# Looking at specific columns! Can call using column names

# %%
df[['D','C','E']]
# Out:
#             D  C  E
# 2022-06-24  4  3  5
# 2022-06-25  3  7  3
# 2022-06-26  3  6  3
# 2022-06-27  6  5  3
# 2022-06-28  4  6  6
# 2022-06-29  6  3  5
# 2022-06-30  7  7  7
# 2022-07-01  7  7  7
# 2022-07-02  4  3  6
# 2022-07-03  6  5  4

# %%
F = df['D'] + df['C'] + df['E']

# %%
F
# Out:
# 2022-06-24    12
# 2022-06-25    13
# 2022-06-26    12
# 2022-06-27    14
# 2022-06-28    16
# 2022-06-29    14
# 2022-06-30    21
# 2022-07-01    21
# 2022-07-02    13
# 2022-07-03    15
# Freq: D, dtype: int64

# %%
#Creating a new column
#df.insert(6, "G", df['D'] + df['C'] + df['A'])
#OR
df['H'] = (df['B']/df['C'])*10

# %%
#df

# %%
#Sort the dataframe based on values in column D
df.sort_values('D', ascending = True)
# Out:
#             A  B  C  D  E          H
# 2022-06-25  5  5  7  3  3   7.142857
# 2022-06-26  6  6  6  3  3  10.000000
# 2022-06-24  7  3  3  4  5  10.000000
# 2022-06-28  5  3  6  4  6   5.000000
# 2022-07-02  5  5  3  4  6  16.666667
# 2022-06-27  6  7  5  6  3  14.000000
# 2022-06-29  7  7  3  6  5  23.333333
# 2022-07-03  7  3  5  6  4   6.000000
# 2022-06-30  6  6  7  7  7   8.571429
# 2022-07-01  5  5  7  7  7   7.142857

# %%
#Change type of values in Dataframe
df.astype("int32")
# Out:
#             A  B  C  D  E   H
# 2022-06-24  7  3  3  4  5  10
# 2022-06-25  5  5  7  3  3   7
# 2022-06-26  6  6  6  3  3  10
# 2022-06-27  6  7  5  6  3  14
# 2022-06-28  5  3  6  4  6   5
# 2022-06-29  7  7  3  6  5  23
# 2022-06-30  6  6  7  7  7   8
# 2022-07-01  5  5  7  7  7   7
# 2022-07-02  5  5  3  4  6  16
# 2022-07-03  7  3  5  6  4   6

# %%
#Boolean Operations
df[df['E'] > 5] #Or df[df.E > 5]
# Out:
#             A  B  C  D  E          H
# 2022-06-28  5  3  6  4  6   5.000000
# 2022-06-30  6  6  7  7  7   8.571429
# 2022-07-01  5  5  7  7  7   7.142857
# 2022-07-02  5  5  3  4  6  16.666667

# %% [markdown]
# Using integer indices to reference columns and rows

# %%
df.iloc[0:3,1:5]
# Out:
#             B  C  D  E
# 2022-06-24  3  3  4  5
# 2022-06-25  5  7  3  3
# 2022-06-26  6  6  3  3

# %%
df.iloc[3:6,1] = np.nan
df
# Out:
#             A    B  C  D  E          H
# 2022-06-24  7  3.0  3  4  5  10.000000
# 2022-06-25  5  5.0  7  3  3   7.142857
# 2022-06-26  6  6.0  6  3  3  10.000000
# 2022-06-27  6  NaN  5  6  3  14.000000
# 2022-06-28  5  NaN  6  4  6   5.000000
# 2022-06-29  7  NaN  3  6  5  23.333333
# 2022-06-30  6  6.0  7  7  7   8.571429
# 2022-07-01  5  5.0  7  7  7   7.142857
# 2022-07-02  5  5.0  3  4  6  16.666667
# 2022-07-03  7  3.0  5  6  4   6.000000

# %%
df.describe()
# Out:
#                A         B          C          D          E          H
# count  10.000000  7.000000  10.000000  10.000000  10.000000  10.000000
# mean    5.900000  4.714286   5.200000   5.000000   4.900000  10.785714
# std     0.875595  1.253566   1.686548   1.563472   1.595131   5.690305
# min     5.000000  3.000000   3.000000   3.000000   3.000000   5.000000
# 25%     5.000000  4.000000   3.500000   4.000000   3.250000   7.142857
# 50%     6.000000  5.000000   5.500000   5.000000   5.000000   9.285714
# 75%     6.750000  5.500000   6.750000   6.000000   6.000000  13.000000
# max     7.000000  6.000000   7.000000   7.000000   7.000000  23.333333

# %%
df.B.fillna(5, inplace = True) #df.dropna --> removes all rows with NaN values
df
# Out:
#             A    B  C  D  E          H
# 2022-06-24  7  3.0  3  4  5  10.000000
# 2022-06-25  5  5.0  7  3  3   7.142857
# 2022-06-26  6  6.0  6  3  3  10.000000
# 2022-06-27  6  5.0  5  6  3  14.000000
# 2022-06-28  5  5.0  6  4  6   5.000000
# 2022-06-29  7  5.0  3  6  5  23.333333
# 2022-06-30  6  6.0  7  7  7   8.571429
# 2022-07-01  5  5.0  7  7  7   7.142857
# 2022-07-02  5  5.0  3  4  6  16.666667
# 2022-07-03  7  3.0  5  6  4   6.000000

# %%
df.to_csv("random.csv")

# %% [markdown]
# ## Real Data with Pandas

# %%
url_europe = 'https://raw.githubusercontent.com/clemsonciti/intro-to-python/master/data3/gapminder_gdp_europe.csv'
data_eur = pd.read_csv(url_europe, index_col='country')
data_eur
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %% [markdown]
# Preview data imported into Dataframe `df`

# %%
data_eur.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733737     9366.067033
# 75%       7236.794919     9597.220820    10931.085348    13277.182058
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
data_eur.T.describe()
# Out:
# country      Albania       Austria       Belgium  Bosnia and Herzegovina  \
# count      12.000000     12.000000     12.000000               12.000000
# mean     3255.366633  20411.916279  19900.758072             3484.779069
# std      1192.351513   9655.281488   8391.186269             1950.522347
# min      1601.056136   6137.076492   8343.105127              973.533195
# 25%      2451.300665  12313.632078  12609.582582             2056.685237
# 50%      3253.238396  20673.252960  20048.910185             3194.325528
# 75%      3657.893725  27555.494175  26071.977175             4427.175044
# max      5937.029526  36126.492700  33692.605080             7446.298803
#
# country      Bulgaria       Croatia  Czech Republic       Denmark  \
# count       12.000000     12.000000       12.000000     12.000000
# mean      6384.055172   9331.712346    13920.011379  21671.824888
# std       2351.963619   3784.408663     4361.646747   8305.077866
# ...

# %%
#data_eur.head(3)
#data_eur.tail(3)

# %% [markdown]
# Extracting a subset of rows and columns

# %%
data_eur.loc["Switzerland":"United Kingdom", "gdpPercap_1957":"gdpPercap_1977"]
# Out:
#                 gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Switzerland       17909.489730    20431.092700    22966.144320
# Turkey             2218.754257     2322.869908     2826.356387
# United Kingdom    11283.177950    12477.177070    14142.850890
#
#                 gdpPercap_1972  gdpPercap_1977
# country
# Switzerland        27195.11304    26982.290520
# Turkey              3450.69638     4269.122326
# United Kingdom     15895.11641    17428.748460

# %%
data_eur.loc["Switzerland":"United Kingdom", "gdpPercap_1957":"gdpPercap_1977"].T.describe()
# Out:
# country   Switzerland       Turkey  United Kingdom
# count        5.000000     5.000000        5.000000
# mean     23096.826062  3017.559852    14245.414156
# std       4059.693970   853.120616     2488.330754
# min      17909.489730  2218.754257    11283.177950
# 25%      20431.092700  2322.869908    12477.177070
# 50%      22966.144320  2826.356387    14142.850890
# 75%      26982.290520  3450.696380    15895.116410
# max      27195.113040  4269.122326    17428.748460

# %%
#data_eur

# %%
subset = data_eur.loc["Italy":"Serbia",:]

# %%
mask = subset > 5000
mask
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy                 False            True            True            True
# Montenegro            False           False           False            True
# Netherlands            True            True            True            True
# Norway                 True            True            True            True
# Poland                False           False            True            True
# Portugal              False           False           False            True
# Romania               False           False           False            True
# Serbia                False           False            True            True
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Italy                  True            True            True            True
# Montenegro             True            True            True            True
# ...

# %%
subset[mask].describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        3.000000        5.000000        8.000000
# mean      9518.496789     9726.274237     9222.642942     9379.578057
# std        815.895062     3017.623171     3716.576995     4217.048863
# min       8941.571858     6248.656232     5338.752143     5907.850937
# 25%       9230.034324     8762.424836     6289.629157     6443.529407
# 50%       9518.496789    11276.193440     8243.582340     7274.429921
# 75%       9806.959254    11465.083240    12790.849560    11357.613822
# max      10095.421720    11653.973040    13450.401510    16361.876470
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count        8.000000        8.000000        8.000000        8.000000
# mean     11671.215660    13798.752152    15056.243445    16727.606892
# std       4699.820161     5545.111849     6184.947861     7752.422494
# ...

# %%
subset[mask].to_csv("test.csv")

# %%
subset_df = pd.read_csv("test.csv", index_col = 'country')
subset_df
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy                   NaN     6248.656232     8243.582340    10022.401310
# Montenegro              NaN             NaN             NaN     5907.850937
# Netherlands     8941.571858    11276.193440    12790.849560    15363.251360
# Norway         10095.421720    11653.973040    13450.401510    16361.876470
# Poland                  NaN             NaN     5338.752143     6557.152776
# Portugal                NaN             NaN             NaN     6361.517993
# Romania                 NaN             NaN             NaN     6470.866545
# Serbia                  NaN             NaN     6289.629157     7991.707066
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Italy          12269.273780    14255.984750    16537.483500    19207.234820
# Montenegro      7778.414017     9595.929905    11222.587620    11732.510170
# ...

# %% [markdown]
# Pandas and Matplotlib: Basic Visualization

# %%
url_oceania = "https://raw.githubusercontent.com/clemsonciti/intro-to-python/master/data3/gapminder_gdp_oceania.csv"
data_o = pd.read_csv(url_oceania, index_col='country')
data_o
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data_o.loc["Australia"].plot()
# Out:
# <Axes: >

# %%
data_o.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
#Converting Column names into Integers
years = data_o.columns.str.strip('gdpPercap_').astype(int)
years
# Out:
# Int64Index([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#             2007],
#            dtype='int64')

# %%
#Renaming column names
data_o.columns = years
data_o
# Out:
#                     1952         1957         1962         1967         1972  \
# country
# Australia    10039.59564  10949.64959  12217.22686  14526.12465  16788.62948
# New Zealand  10556.57566  12247.39532  13175.67800  14463.91893  16046.03728
#
#                     1977         1982         1987         1992         1997  \
# country
# Australia    18334.19751  19477.00928  21888.88903  23424.76683  26997.93657
# New Zealand  16233.71770  17632.41040  19007.19129  18363.32494  21050.41377
#
#                     2002         2007
# country
# Australia    30687.75473  34435.36744
# New Zealand  23189.80135  25185.00911

# %%
data_o.loc["Australia"].plot()
# Out:
# <Axes: >

# %%
data_o.T.plot()
plt.ylabel('GDP per capita')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
#Changing style of plot
plt.style.use('ggplot')
data_o.T.plot()
plt.ylabel('GDP per capita')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
#Style change persists
data_o.loc["Australia"].plot()
# Out:
# <Axes: >

# %%
gdp_nz = data_o.loc["New Zealand"]
gdp_aus = data_o.loc["Australia"]
#gdp_nz

# %%
data_o[1987]
# Out:
# country
# Australia      21888.88903
# New Zealand    19007.19129
# Name: 1987, dtype: float64

# %%
plt.style.use('default')
plt.plot(years,gdp_aus,"g-.", label="Australia")
plt.plot(years,gdp_nz,"r--", label="New Zealand")
##Plotting one specific point
plt.plot(1987,data_o.loc["Australia",1987],"bx")
#Axis labels
plt.ylabel('GDP per capita')
plt.xlabel('Years')
#adding legend
plt.legend(loc="best")
#plt.xticks(rotation=60)
plt.savefig("oceania.png")

# %%
#plt.xticks?

# %%
data_eur.min().plot(label="minimum GDP")
data_eur.max().plot(label="maximum GDP")
plt.legend(loc="best")
plt.xticks(rotation=60) #Rotating to fit
plt.ylabel('GDP per capita')
plt.xlabel('Years')
plt.savefig("min_max_GDP_europe.png", bbox_inches='tight')

# %%
plt.savefig?
# Out:
# Signature: plt.savefig(*args, **kwargs)
# Docstring:
# Save the current figure.
#
# Call signature::
#
#   savefig(fname, *, dpi='figure', format=None, metadata=None,
#           bbox_inches=None, pad_inches=0.1,
#           facecolor='auto', edgecolor='auto',
#           backend=None, **kwargs
#          )
#
# The available output formats depend on the backend being used.
#
# Parameters
# ----------
# fname : str or path-like or binary file-like
#     A path, or a Python file-like object, or
#     possibly some backend-dependent object such as
#     `matplotlib.backends.backend_pdf.PdfPages`.
#
#     If *format* is set, it determines the output format, and the file
#     is saved as *fname*.  Note that *fname* is used verbatim, and there
#     is no attempt to make the extension, if any, of *fname* match
#     *format*, and no extension is appended.
#
#     If *format* is not set, then the format is inferred from the
#     extension of *fname*, if there is one.  If *format* is not
# ...

# %%
plt.style.use?
# Out:
# Signature: plt.style.use(style)
# Docstring:
# Use Matplotlib style settings from a style specification.
#
# The style name of 'default' is reserved for reverting back to
# the default style settings.
#
# .. note::
#
#    This updates the `.rcParams` with the settings from the style.
#    `.rcParams` not defined in the style are kept.
#
# Parameters
# ----------
# style : str, dict, Path or list
#
#     A style specification. Valid options are:
#
#     str
#         - One of the style names in `.style.available` (a builtin style or
#           a style installed in the user library path).
#
#         - A dotted name of the form "package.style_name"; in that case,
#           "package" should be an importable Python package name, e.g. at
#           ``/path/to/package/__init__.py``; the loaded style file is
#           ``/path/to/package/style_name.mplstyle``.  (Style files in
#           subpackages are likewise supported.)
#
# ...

# %% [markdown]
# ## Split, Apply, Combine
# "Split, Apply, Combine" refers to the common practice of splitting up a dataset into relevant chunks, doing some computation on those chunks, then combining the output into a single table. In pandas, we can break up the data into groups using the `groupby` method. We can then apply our computation on the grouped data. If we set things up right, pandas will combine the results automatically. [Image credit](https://andeekaplan.com/images/blog/01202014split-apply-combine.png).

# %% [markdown]
# ![Split apply combine](https://raw.githubusercontent.com/clemsonciti/rcde_workshops/master/fig/split-apply-combine.png)

# %% [markdown]
# We will work with the famous [iris dataset](https://archive.ics.uci.edu/ml/datasets/iris).

# %%
# load the data
df = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### `groupby`

# %% [markdown]
# Group by allows us to split up the data.

# %%
# what do we get just call groupby? 
df.groupby('variety')
# answer: a special DataFrameGroupBy object

# %%
# we can iterate over this data structure manually: 
for g, d in df.groupby('variety'): 
    print(g)
    display(d.head(2))
# Out:
# Setosa
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# Versicolor
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# Virginica
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica

# %%
# we can even perform split-apply-combine manually
# for instance, we can compute the average 'sepal.length' for each set

variety = []
sepal_length = []

# 1. Split
for g, d in df.groupby('variety'): 
    variety.append(g)
    # 2. Apply:
    sepal_length.append(d['sepal.length'].mean())
    
# 3. Combine
pd.DataFrame({'variety': variety, 'sepal.length': sepal_length})
# Out:
#       variety  sepal.length
# 0      Setosa         5.006
# 1  Versicolor         5.936
# 2   Virginica         6.588

# %%
# but this is such a common workflow that pandas makes it easy
df.groupby('variety', as_index=False)['sepal.length'].mean()
# Out:
#       variety  sepal.length
# 0      Setosa         5.006
# 1  Versicolor         5.936
# 2   Virginica         6.588

# %%
# and, using the pandas way, we can compute the mean of all variables without writing more code
df.groupby('variety', as_index=False).mean()
# Out:
#       variety  sepal.length  sepal.width  petal.length  petal.width
# 0      Setosa         5.006        3.428         1.462        0.246
# 1  Versicolor         5.936        2.770         4.260        1.326
# 2   Virginica         6.588        2.974         5.552        2.026

# %%
# we can even compute multiple metrics per column using the `agg` method:
df.groupby('variety', as_index=False).agg(['mean', 'std', 'sem', 'count'])
# advanced note: because we have multiple functions for each variable, pandas has created a multi-index for the columns
# Out:
#            sepal.length                           sepal.width            \
#                    mean       std       sem count        mean       std
# variety
# Setosa            5.006  0.352490  0.049850    50       3.428  0.379064
# Versicolor        5.936  0.516171  0.072998    50       2.770  0.313798
# Virginica         6.588  0.635880  0.089927    50       2.974  0.322497
#
#                            petal.length                           petal.width  \
#                  sem count         mean       std       sem count        mean
# variety
# Setosa      0.053608    50        1.462  0.173664  0.024560    50       0.246
# Versicolor  0.044378    50        4.260  0.469911  0.066455    50       1.326
# Virginica   0.045608    50        5.552  0.551895  0.078050    50       2.026
#
#
#                  std       sem count
# variety
# Setosa      0.105386  0.014904    50
# Versicolor  0.197753  0.027966    50
# Virginica   0.274650  0.038841    50

# %%
# pretty colors if you want
df.groupby('variety').agg(['mean', 'std', 'sem', 'count']).style.background_gradient('Blues')
# Out:
# <style type="text/css">
# #T_227d4_row0_col0, #T_227d4_row0_col1, #T_227d4_row0_col2, #T_227d4_row0_col3, #T_227d4_row0_col7, #T_227d4_row0_col8, #T_227d4_row0_col9, #T_227d4_row0_col10, #T_227d4_row0_col11, #T_227d4_row0_col12, #T_227d4_row0_col13, #T_227d4_row0_col14, #T_227d4_row0_col15, #T_227d4_row1_col3, #T_227d4_row1_col4, #T_227d4_row1_col5, #T_227d4_row1_col6, #T_227d4_row1_col7, #T_227d4_row1_col11, #T_227d4_row1_col15, #T_227d4_row2_col3, #T_227d4_row2_col7, #T_227d4_row2_col11, #T_227d4_row2_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_227d4_row0_col4, #T_227d4_row0_col5, #T_227d4_row0_col6, #T_227d4_row2_col0, #T_227d4_row2_col1, #T_227d4_row2_col2, #T_227d4_row2_col8, #T_227d4_row2_col9, #T_227d4_row2_col10, #T_227d4_row2_col12, #T_227d4_row2_col13, #T_227d4_row2_col14 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_227d4_row1_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_227d4_row1_col1, #T_227d4_row1_col2 {
# ...

# %% [markdown]
# ## `apply`

# %% [markdown]
# The above methods worked because pandas implements special "mean", "std", "sem", and "count"
# for the grouped data frame object. But what if we want to apply some strange function
# to the grouped data, and pandas doesn't implement that function?
#
# For example, say we wanted to apply standard-normal scaling to the `sepal.length` variable within each
# `variety` group? If $x$ is `sepal.length`, we want to compute a new variable
# $$
# x' = \frac{x - \mu_x}{\sigma_x}
# $$
# where $\mu_x$ and $\sigma_x$ are computed separately within each `variety`.
#
# How do we do this in pandas? This is where the `apply` method comes in. Though apply is very powerful and takes some getting used to. See [the documentation](https://pandas.pydata.org/docs/user_guide/groupby.html) for more tricks.

# %%
# first define a function that applies to a specific element
def standard_scaler(data):
    """convert to string and get the first character"""
    return (data - data.mean()) / data.std()

# then use apply to loop the function over the column
df_scaled = df.set_index('variety').groupby('variety', group_keys=False).apply(standard_scaler)
df_scaled
# printed out means in each group to prove that scaling was per-group rather than global
# Out:
#            sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa         0.266674     0.189941     -0.357011    -0.436492
# Setosa        -0.300718    -1.129096     -0.357011    -0.436492
# Setosa        -0.868111    -0.601481     -0.932836    -0.436492
# Setosa        -1.151807    -0.865288      0.218813    -0.436492
# Setosa        -0.017022     0.453749     -0.357011    -0.436492
# ...                 ...          ...           ...          ...
# Virginica      0.176134     0.080621     -0.637803     0.997633
# Virginica     -0.452916    -1.469783     -1.000191    -0.458766
# Virginica     -0.138391     0.080621     -0.637803    -0.094666
# Virginica     -0.610178     1.320944     -0.275415     0.997633
# Virginica     -1.081966     0.080621     -0.818997    -0.822865
#
# [150 rows x 4 columns]

# %%
print("Original variables:")
_ = df.set_index('variety').hist()
# Out:
# Original variables:

# %%
print("Scaled variables:")
_ = df_scaled.hist()
# Out:
# Scaled variables:

# %% [markdown]
# ## `melt`

# %% [markdown]
# Often our data contains multiple measurements, with each measurement using one column. Sometimes, it is more convenient to place all of the measurements in a single column, with an additional column to indicate which measurement the value represents.
#
# Take for example the iris dataset.
#
# Original:

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# Melted version:

# %%
df.melt(id_vars = ['variety'])
# Out:
#        variety      variable  value
# 0       Setosa  sepal.length    5.1
# 1       Setosa  sepal.length    4.9
# 2       Setosa  sepal.length    4.7
# 3       Setosa  sepal.length    4.6
# 4       Setosa  sepal.length    5.0
# ..         ...           ...    ...
# 595  Virginica   petal.width    2.3
# 596  Virginica   petal.width    1.9
# 597  Virginica   petal.width    2.0
# 598  Virginica   petal.width    2.3
# 599  Virginica   petal.width    1.8
#
# [600 rows x 3 columns]

# %% [markdown]
# Notice that this results in a much longer dataframe.  By default, pandas assigns the names `variable` and `value` to the column giving the measurement name and the column holding the measurement itself, respectively. We can change these by passing in the right arguments:

# %%
df.melt(id_vars = ['variety'], var_name='measurement_name', value_name='measurement_value')
# Out:
#        variety measurement_name  measurement_value
# 0       Setosa     sepal.length                5.1
# 1       Setosa     sepal.length                4.9
# 2       Setosa     sepal.length                4.7
# 3       Setosa     sepal.length                4.6
# 4       Setosa     sepal.length                5.0
# ..         ...              ...                ...
# 595  Virginica      petal.width                2.3
# 596  Virginica      petal.width                1.9
# 597  Virginica      petal.width                2.0
# 598  Virginica      petal.width                2.3
# 599  Virginica      petal.width                1.8
#
# [600 rows x 3 columns]

# %% [markdown]
# ---
#
# **Question**: Why would we want to melt a dataframe?
#
# ---

# %%
df_melted = df.melt(id_vars = ['variety'])

df_melted.head()
# Out:
#   variety      variable  value
# 0  Setosa  sepal.length    5.1
# 1  Setosa  sepal.length    4.9
# 2  Setosa  sepal.length    4.7
# 3  Setosa  sepal.length    4.6
# 4  Setosa  sepal.length    5.0

# %%
df_melted.groupby(['variety', 'variable']).agg(['mean', 'sem'])
# Out:
#                          value
#                           mean       sem
# variety    variable
# Setosa     petal.length  1.462  0.024560
#            petal.width   0.246  0.014904
#            sepal.length  5.006  0.049850
#            sepal.width   3.428  0.053608
# Versicolor petal.length  4.260  0.066455
#            petal.width   1.326  0.027966
#            sepal.length  5.936  0.072998
#            sepal.width   2.770  0.044378
# Virginica  petal.length  5.552  0.078050
#            petal.width   2.026  0.038841
#            sepal.length  6.588  0.089927
#            sepal.width   2.974  0.045608

# %% [markdown]
# Compare this with the same operation on the original data

# %%
df.groupby(['variety']).agg(['mean', 'sem'])
# Out:
#            sepal.length           sepal.width           petal.length  \
#                    mean       sem        mean       sem         mean
# variety
# Setosa            5.006  0.049850       3.428  0.053608        1.462
# Versicolor        5.936  0.072998       2.770  0.044378        4.260
# Virginica         6.588  0.089927       2.974  0.045608        5.552
#
#                      petal.width
#                  sem        mean       sem
# variety
# Setosa      0.024560       0.246  0.014904
# Versicolor  0.066455       1.326  0.027966
# Virginica   0.078050       2.026  0.038841

# %%
for key, group in df_melted.groupby(['variety', 'variable']):
    plt.hist(group['value'], label=" ".join(key))
_ = plt.legend()

# %% [markdown]
# Compare with how we have to produce this plot from the original dataframe:

# %%
for key, group in df.groupby('variety'):
    for col in ["sepal.length", "sepal.width", "petal.length", "petal.width"]:
        plt.hist(group[col], label=f"{key} {col}")
_ = plt.legend()

# %% [markdown]
# ## `pivot_table`

# %% [markdown]
# `pivot_table` is the conceptually the opposite of `melt`. It allows us to convert a column with variable names into multiple columns.
#
# Let's use pivot table on our melted dataframe.  To do so, we need to specify the following:
#
# * `index`: which columns will be used to uniquely specify the rows in the resulting dataframe. In this case, we want `variety`.
# * `columns`: which columns will be converted into new columns in the resulting dataframe. In this case, we want `variable`.
# * `values`: which column contains the values that will be used to populate the new dataframe. In this case, we want `value`.

# %%
df_melted.pivot_table(index = 'variety', columns='variable', values='value')
# Out:
# variable    petal.length  petal.width  sepal.length  sepal.width
# variety
# Setosa             1.462        0.246         5.006        3.428
# Versicolor         4.260        1.326         5.936        2.770
# Virginica          5.552        2.026         6.588        2.974

# %% [markdown]
# Notice that we only have 3 rows! This is because the provided index (`variety`) does not uniquely specify the original rows in our dataframe. When pivoting, pandas applied the default aggregation function -- `mean` -- to fill the cells.
#
# We can change the aggregation function as needed:

# %%
df_melted.pivot_table(index = 'variety', columns='variable', values='value', aggfunc='max')
# Out:
# variable    petal.length  petal.width  sepal.length  sepal.width
# variety
# Setosa               1.9          0.6           5.8          4.4
# Versicolor           5.1          1.8           7.0          3.4
# Virginica            6.9          2.5           7.9          3.8

# %%
df_melted.pivot_table(index = 'variety', columns='variable', values='value', aggfunc=lambda x: f"{x.mean():0.2f}+/-{1.96*x.sem():0.2f}")
# Out:
# variable   petal.length  petal.width sepal.length  sepal.width
# variety
# Setosa      1.46+/-0.05  0.25+/-0.03  5.01+/-0.10  3.43+/-0.11
# Versicolor  4.26+/-0.13  1.33+/-0.05  5.94+/-0.14  2.77+/-0.09
# Virginica   5.55+/-0.15  2.03+/-0.08  6.59+/-0.18  2.97+/-0.09

# %% [markdown]
# ## Random Walk
#
# https://en.wikipedia.org/wiki/Random_walk
#
# We start at a position (0) and flip a coin. Based on the result of the coin, heads or tails, we take a step forward or backward. We flip the coin a 100 times and then plot the path we took and our final position.
# We can repeat this experiment multiple times to see the variation in each Random Walk.

# %% [markdown]
# Examples/Solutions for Random Walk

# %%
def random_walk(num_steps):
    walk = np.zeros(num_steps)
    for step in range(len(walk)):
        #Coin flip result
        coin_flip_result = np.random.randint(2)
        if coin_flip_result == 0:
            #Heads
            walk[step] = walk[step-1]+1
        else:
            #Tails
            walk[step] = walk[step-1]-1
    plt.plot(walk)

# %%
# %%time
walk_range = 1000
num_steps = 200
for walk in range(walk_range):
    random_walk(num_steps)
# Out:
# CPU times: user 2.54 s, sys: 48.9 ms, total: 2.59 s
# Wall time: 2.61 s

# %%
def Path(step_direction):
    heads = 0
    tails = 1
    x_range = np.linspace(0,100,100)
    coins = np.random.randint(heads,tails+1,100)
    step_direction = []
    for i in coins:
        if i == heads:
            step_direction.append(1)
        else:
            step_direction.append(-1)
    step = np.cumsum(step_direction)
    plt.plot(x_range,step)

# %%
# %%time
for i in range(walk_range):
    Path(num_steps)
# Out:
# CPU times: user 997 ms, sys: 10.6 ms, total: 1.01 s
# Wall time: 1.01 s

# %%
plt.plot(np.cumsum([1 if i else -1 for i in np.random.randint(2, size=num_steps)]))

# %%
# %%time
for walk in range(walk_range):
    plt.plot(np.cumsum([1 if i else -1 for i in np.random.randint(2, size=num_steps)]))
# Out:
# CPU times: user 1 s, sys: 31.2 ms, total: 1.03 s
# Wall time: 1.04 s
